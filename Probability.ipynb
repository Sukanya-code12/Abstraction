# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukanya-code12/Abstraction/blob/main/Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def pick_ball_experiment():
  balls=['Blue','Red','Green']
  result=random.choice(balls)
  pro=balls.count('Red')/len(balls)
  print("Probability of Picking Red Ball is:", pro)
  if result=='Red':
    return 'Red Ball was Picked'
  else:
    return 'Better Luck Next Time'
res=pick_ball_experiment()
print(res)
# Out:
# Probability of Picking Red Ball is: 0.3333333333333333
# Red Ball was Picked
